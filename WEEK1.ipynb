# %% [markdown]
# Input and Output formatting functions

# %%
print("mithra")
# Out:
# mithra

# %%
num = float(input("Enter a number: "))
# Out:
# Enter a number: 5

# %%
name = input("Enter your name: ")
print("Hello,", name)
# Out:
# Enter your name: Mithra
# Hello, Mithra

# %%
name = "Mithra"
print(name)
# Out:
# Mithra

# %%
a = 10
b = 20
print(a, b)
# Out:
# 10 20

# %%
name = "Mithra"
age = 18
print(f"Hello, {name}")
print(f"I am {age} years old.")
# Out:
# Hello, Mithra
# I am 18 years old.

# %%
name = "Mithra"
age = 18

print("My name is {} and I am {} years old.".format(name, age))
# Out:
# My name is Mithra and I am 18 years old.

# %%
pi = 3.14159265
print("%f" % pi)
# Out:
# 3.141593

# %%
name = "Mithra"
marks = 95.5

print("Name: %s, Marks: %.1f" % (name, marks))
# Out:
# Name: Mithra, Marks: 95.5

# %% [markdown]
# Topic: Input, Output and Formatted Output

# %%
print("Welcome to Python")
# Out:
# Welcome to Python

# %%
print(25)
print(50)
# Out:
# 25
# 50

# %%
name = "Rahul"
print(name)
# Out:
# Rahul

# %%
a = 15
b = 10
print(a,b)
# Out:
# 15 10

# %%
a = 20
b = 4
print(a)
print(b)
# Out:
# 20
# 4

# %%
a = 20
b = 3

print (a,b)
# Out:
# 20 3

# %%
name = "Anjali"
age = 19
print(name)
print(age)
# Out:
# Anjali
# 19

# %%
name = "Priya"
print(f"{name}")
# Out:
# Priya

# %%
city = "Hyderabad"
print("I live in {}".format(city))
# Out:
# I live in Hyderabad

# %%
name = "Kiran"
print("hello,%s" % name)
# Out:
# hello,Kiran

# %%
a = 5
b = 4
print(a,b)
# Out:
# 5 4

# %%
x = 2
print(x)
# Out:
# 2

# %%
num = 25
print(num)
# Out:
# 25

# %%
value = 15.522222
print(type(value))
# Out:
# <class 'float'>

# %%
value = 15.522222
print(f"{value:.2f}")
# Out:
# 15.52

# %%
name = "Asha"
marks = 92
print(f"hello {name}")
print(f"Marks:{marks}")
# Out:
# hello Asha
# Marks:92

# %%
print("Python", "Programming", "Language")
# Out:
# Python Programming Language

# %%
a = 10
b = 20
print("Sum =", a + b)
# Out:
# Sum = 30

# %%
name = "Rahul"
print(name * 3)
# Out:
# RahulRahulRahul

# %%
age = input("Enter Age:")
# Out:
# Enter Age:18

# %%
x = 10
y = 20

print(f"x = {x}, y = {y}")
print(f"sum={x+y}")
# Out:
# x = 10, y = 20
# sum=30

# %%
name = "Amit"
cgpa = 8.75
print(name)
print(cgpa)
# Out:
# Amit
# 8.75

# %% [markdown]
# Using Functions in Python

# %% [markdown]
# 1. DEFINING A BASIC FUNCTION

# %%
def greet():
    print("Hello! Welcome to Python Functions.")
greet()
# Out:
# Hello! Welcome to Python Functions.

# %% [markdown]
# 2. FUNCTION WITH PARAMETERS

# %%
def greet_user(name):
    print(f"Hello, {name}!")
greet user("Alice")
greet_user("Bob")
# Out:
# Hello, Alice!
# Hello, Bob!

# %% [markdown]
# 3. FUNCTION WITH DEFAULT PARAMETERS

# %%
def greet_user(name="Guest"):
    print(f"Welcome, {name}!")
greet_user()
greet_user("Ravi")
# Out:
# Welcome, Guest!
# Welcome, Ravi!

# %% [markdown]
#  5. USING *args

# %%
def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)
print_names("Alice", "bob", "Charlie")
# Out:
# Names passed: ('Alice', 'bob', 'Charlie')
# Hello Alice
# Hello bob
# Hello Charlie

# %% [markdown]
#  6. USING **kwargs

# %%
def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")
print_info(name="Alice", age=25, city="Delhi")
# Out:
# User Info:
# name = Alice
# age = 25
# city = Delhi

# %% [markdown]
#  7. COMBINING *args AND **kwargs

# %%
def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)
show_details(1, 2, 3, name="Mithra", city="Hyderabad")
# Out:
# Args: (1, 2, 3)
# Kwargs: {'name': 'Mithra', 'city': 'Hyderabad'}

# %% [markdown]
# 8. FUNCTION NESTING

# %%
def multiply(a, b):
    return a * b
def square(n):
    return multiply(n, n)
print("Square of 4:", square(4))
# Out:
# Square of 4: 16
