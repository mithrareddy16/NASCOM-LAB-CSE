# %%
import pandas as pd
import numpy as np
s = pd.Series([100, 200, 300, 400], index=['i', 'ii', 'iii', 'iv'])
print("\nSeries:")
print(s)
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [21, 24, 27, 29],
    'Salary': [50000, 60000, 70000, 80000]
}
df = pd.DataFrame(data)
print("\nDataFrame:")
print(df)
# Out:
# Series:
# i      100
# ii     200
# iii    300
# iv     400
# dtype: int64
#
# DataFrame:
#       Name  Age  Salary
# 0    Alice   21   50000
# 1      Bob   24   60000
# 2  Charlie   27   70000
# 3    David   29   80000

# %%
array = np.array([[1, 2], [3, 4], [5, 6]])
df_from_array = pd.DataFrame(array, columns=['Column1', 'Column2'])
print("\nDataFrame from NumPy array:")
print(df_from_array)
# Out:
# DataFrame from NumPy array:
#    Column1  Column2
# 0        1        2
# 1        3        4
# 2        5        6

# %%
print("\nRow with label 1 using loc:")
print(df.loc[1])
# Out:
# Row with label 1 using loc:
# Name        Bob
# Age          24
# Salary    60000
# Name: 1, dtype: object

# %%
print("\nFirst two rows using iloc:")
print(df.iloc[0:2])
# Out:
# First two rows using iloc:
#     Name  Age  Salary
# 0  Alice   21   50000
# 1    Bob   24   60000

# %%
print("\nSelect 'Name' column:")
print(df['Name'])
print("\nSelect 'Name' and 'Age' columns:")
print(df[['Name', 'Age']])
print("\nRows where Salary > 60000:")
print(df[df['Salary'] > 60000])
# Out:
# Select 'Name' column:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: object
#
# Select 'Name' and 'Age' columns:
#       Name  Age
# 0    Alice   21
# 1      Bob   24
# 2  Charlie   27
# 3    David   29
#
# Rows where Salary > 60000:
#       Name  Age  Salary
# 2  Charlie   27   70000
# 3    David   29   80000

# %%
data_dirty = {
    'Name': ['Alice', None, 'Charlie', 'David'],
    'Age': [21, 24, None, 29],
    'Salary': [50000, 60000, None, 80000]
}
df_dirty = pd.DataFrame(data_dirty)
print("\nOriginal Dirty DataFrame:")
print(df_dirty)
# Out:
# Original Dirty DataFrame:
#       Name   Age   Salary
# 0    Alice  21.0  50000.0
# 1     None  24.0  60000.0
# 2  Charlie   NaN      NaN
# 3    David  29.0  80000.0

# %%
print("\nFill missing values with a specific value:")
print(df_dirty.fillna({'Name': 'Unknown', 'Age': df_dirty['Age'].mean(), 'Salary': 0}))
# Out:
# Fill missing values with a specific value:
#       Name        Age   Salary
# 0    Alice  21.000000  50000.0
# 1  Unknown  24.000000  60000.0
# 2  Charlie  24.666667      0.0
# 3    David  29.000000  80000.0

# %%
print("\nBoolean DataFrame for missing values:")
print(df_dirty.isnull())
# Out:
# Boolean DataFrame for missing values:
#     Name    Age  Salary
# 0  False  False   False
# 1   True  False   False
# 2  False   True    True
# 3  False  False   False

# %%
df['Bonus'] = df['Salary'] * 0.1
print("\nDataFrame with Bonus column:")
print(df)
print("\nRename columns:")
df_renamed = df.rename(columns={'Salary': 'BaseSalary'})
print(df_renamed)
print("\nSort by Age descending:")
print(df.sort_values(by='Age', ascending=False))
print("\nGroup by operation (average salary by age > 30 or not):")
df['AgeGroup'] = df['Age'] > 30
print(df.groupby('AgeGroup')['Salary'].mean())
# Out:
# DataFrame with Bonus column:
#       Name  Age  Salary   Bonus
# 0    Alice   21   50000  5000.0
# 1      Bob   24   60000  6000.0
# 2  Charlie   27   70000  7000.0
# 3    David   29   80000  8000.0
#
# Rename columns:
#       Name  Age  BaseSalary   Bonus
# 0    Alice   21       50000  5000.0
# 1      Bob   24       60000  6000.0
# 2  Charlie   27       70000  7000.0
# 3    David   29       80000  8000.0
#
# Sort by Age descending:
#       Name  Age  Salary   Bonus
# 3    David   29   80000  8000.0
# 2  Charlie   27   70000  7000.0
# 1      Bob   24   60000  6000.0
# 0    Alice   21   50000  5000.0
#
# Group by operation (average salary by age > 30 or not):
# AgeGroup
# False    65000.0
# Name: Salary, dtype: float64

# %%
import pandas as pd
import numpy as np
np.random.seed(1)
num_rows = 10
df_synth = pd.DataFrame({
    'ID': np.arange(1, num_rows + 1),
    'Score': np.random.randint(50, 100, size=num_rows),
    'Passed': np.random.choice([True, False], size=num_rows)
})
print("\nSynthetic DataFrame:")
print(df_synth)
# Out:
# Synthetic DataFrame:
#    ID  Score  Passed
# 0   1     87   False
# 1   2     93    True
# 2   3     62   False
# 3   4     58   False
# 4   5     59    True
# 5   6     61    True
# 6   7     55   False
# 7   8     65    True
# 8   9     50    True
# 9  10     66    True

# %%
print("\nStudents who passed:")
print(df_synth[df_synth['Passed'] == True])
print("\nAverage score of failed students:")
print(df_synth[df_synth['Passed'] == False]['Score'].mean())
# Out:
# Students who passed:
#    ID  Score  Passed
# 1   2     93    True
# 4   5     59    True
# 5   6     61    True
# 7   8     65    True
# 8   9     50    True
# 9  10     66    True
#
# Average score of failed students:
# 65.5

# %%
print("\nDataFrame info:")
df.info()
print("\nDataFrame describe:")
print(df.describe())
# Out:
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      4 non-null      object
#  1   Age       4 non-null      int64
#  2   Salary    4 non-null      int64
#  3   Bonus     4 non-null      float64
#  4   AgeGroup  4 non-null      bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 264.0+ bytes
#
# DataFrame describe:
#          Age        Salary        Bonus
# count   4.00      4.000000     4.000000
# mean   25.25  65000.000000  6500.000000
# std     3.50  12909.944487  1290.994449
# min    21.00  50000.000000  5000.000000
# 25%    23.25  57500.000000  5750.000000
# 50%    25.50  65000.000000  6500.000000
# 75%    27.50  72500.000000  7250.000000
# max    29.00  80000.000000  8000.000000

# %%
print("\nData types of each column:")
print(df.dtypes)
print("\nFirst 3 rows:")
print(df.head(3))
print("\nLast 2 rows:")
print(df.tail(2))
# Out:
# Data types of each column:
# Name         object
# Age           int64
# Salary        int64
# Bonus       float64
# AgeGroup       bool
# dtype: object
#
# First 3 rows:
#       Name  Age  Salary   Bonus  AgeGroup
# 0    Alice   21   50000  5000.0     False
# 1      Bob   24   60000  6000.0     False
# 2  Charlie   27   70000  7000.0     False
#
# Last 2 rows:
#       Name  Age  Salary   Bonus  AgeGroup
# 2  Charlie   27   70000  7000.0     False
# 3    David   29   80000  8000.0     False

# %%
print("\nMean Age:", df['Age'].mean())
print("Median Salary:", df['Salary'].median())
print("Mode of Bonus:")
print(df['Bonus'].mode())
print("Standard Deviation of Salary:", df['Salary'].std())
print("Variance of Salary:", df['Salary'].var())
# Out:
# Mean Age: 25.25
# Median Salary: 65000.0
# Mode of Bonus:
# 0    5000.0
# 1    6000.0
# 2    7000.0
# 3    8000.0
# Name: Bonus, dtype: float64
# Standard Deviation of Salary: 12909.944487358056
# Variance of Salary: 166666666.66666666

# %%
print("\nCorrelation between Age and Salary:")
print(df[['Age', 'Salary']].corr())
print("\nCovariance between Age and Salary:")
print(df[['Age', 'Salary']].cov())
print("\nValue counts for AgeGroup:")
print(df['AgeGroup'].value_counts())
# Out:
# Correlation between Age and Salary:
#             Age   Salary
# Age     1.00000  0.99591
# Salary  0.99591  1.00000
#
# Covariance between Age and Salary:
#              Age        Salary
# Age        12.25  4.500000e+04
# Salary  45000.00  1.666667e+08
#
# Value counts for AgeGroup:
# AgeGroup
# False    4
# Name: count, dtype: int64

# %%
print("\nCumulative sum of Salary:")
print(df['Salary'].cumsum())

print("\nCumulative max of Salary:")
print(df['Salary'].cummax())

print("\nRank of Salary:")
print(df['Salary'].rank())

print("\nQuantiles of Salary:")
print(df['Salary'].quantile([0.25, 0.5, 0.75]))
# Out:
# Cumulative sum of Salary:
# 0     50000
# 1    110000
# 2    180000
# 3    260000
# Name: Salary, dtype: int64
#
# Cumulative max of Salary:
# 0    50000
# 1    60000
# 2    70000
# 3    80000
# Name: Salary, dtype: int64
#
# Rank of Salary:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# Name: Salary, dtype: float64
#
# Quantiles of Salary:
# 0.25    57500.0
# 0.50    65000.0
# 0.75    72500.0
# Name: Salary, dtype: float64
