# %% [markdown]
#  Basic Try-Except Block

# %%
try:
    x = int(input("Enter a number: "))
    print("You entered:", x)
except ValueError:
    print("That was not a valid number!")
# Out:
# Enter a number: 78
# You entered: 78

# %% [markdown]
#  Try-Except-Else-Finally Structure

# %%
try:
    num = int(input("Enter a number to divide 100: "))
    result = 100 / num
except ZeroDivisionError:
    print("Cannot divide by zero!")
except ValueError:
    print("Invalid input! Not a number.")
else:
    print("Result is:", result)
finally:
    print("Execution complete. This block always runs.")
# Out:
# Enter a number to divide 100: 35
# Result is: 2.857142857142857
# Execution complete. This block always runs.

# %% [markdown]
#   Catching Multiple Exceptions

# %%
try:
    a = int("ten")
    b = 10 / 0
except (ValueError, ZeroDivisionError) as e:
    print("An error occurred:", e)
# Out:
# An error occurred: invalid literal for int() with base 10: 'ten'

# %% [markdown]
#   Raising Custom Exceptions

# %%
def check_age(age):
    if age < 0:
        raise ValueError("Age cannot be negative!")
    else:
        print("Age is valid.")

try:
    check_age(-5)
except ValueError as e:
    print("Caught an exception:", e)
# Out:
# Caught an exception: Age cannot be negative!

# %% [markdown]
#  DEBUGGING PRACTICES
#
#  A. Using print() statements

# %%
def divide(a, b):
    print(f"Dividing {a} by {b}")
    return a / b

print(divide(70, 5))
# Out:
# Dividing 70 by 5
# 14.0

# %% [markdown]
#  Using the Python Debugger

# %%
def calculate_total(price, quantity):
    return price * quantity
print(calculate_total(99, 3))
# Out:
# 297

# %%
import os
print("Current Directory:", os.getcwd())
print("Files and Folders:", os.listdir())
os.mkdir("demo_folder")
os.rename("demo_folder", "renamed_folder")
os.rmdir("renamed_folder")
# Out:
# Current Directory: /content
# Files and Folders: ['.config', 'sample_data']

# %%
from datetime import datetime, date, timedelta
now = datetime.now()
print("Now:", now)
today = date.today()
print("Today's Date:", today)
dob = date(2008, 1, 1)
print("DOB:", dob)
yesterday = today - timedelta(days=1)
tomorrow = today + timedelta(days=1)
print("Yesterday:", yesterday)
print("Tomorrow:", tomorrow)
formatted = now.strftime("%d-%m-%Y %H:%M:%S")
print("Formatted DateTime:", formatted)
# Out:
# Now: 2026-08-24 09:17:51.805459
# Today's Date: 2026-08-24
# DOB: 2008-01-01
# Yesterday: 2026-08-23
# Tomorrow: 2026-08-25
# Formatted DateTime: 24-08-2026 09:17:51

# %%
import random
print("Random Int:", random.randint(1, 100))
print("Random Float:", random.random())
colors = ['yellow', 'purple', 'blue']
print("Random Color:", random.choice(colors))
random.shuffle(colors)
print("Shuffled List:", colors)
print("Sample:", random.sample(range(1, 40), 4))
# Out:
# Random Int: 18
# Random Float: 0.23311788107510212
# Random Color: purple
# Shuffled List: ['yellow', 'blue', 'purple']
# Sample: [14, 2, 6, 32]

# %%
from collections import Counter
fruits = ['apple', 'banana', 'apple', 'watermelon', 'banana', 'orange']
count = Counter(fruits)
print("Fruit Count:", count)
# Out:
# Fruit Count: Counter({'apple': 2, 'banana': 2, 'watermelon': 1, 'orange': 1})

# %%
from collections import defaultdict
marks = defaultdict(lambda: 0)
marks['Math'] = 98
marks['Science'] = 85
print("English Marks (not set):", marks['English'])
# Out:
# English Marks (not set): 0

# %%
from collections import namedtuple
Point = namedtuple('Point', 'x y')
p1 = Point(20, 40)
print("Point:", p1)
print("x:", p1.x, "y:", p1.y)
# Out:
# Point: Point(x=20, y=40)
# x: 20 y: 40

# %%
from collections import deque
dq = deque([1, 2, 3])
dq.append(4)
dq.appendleft(0)
dq.pop()
dq.popleft()
print("Deque after operations:", dq)
# Out:
# Deque after operations: deque([1, 2, 3])
